# %% [markdown]
# #### This is my first AI class in Ibadan

# %%
1 = 2
# Out:
#   File "<ipython-input-1-c0ab9e3898ea>", line 1
#     1 = 2
#          ^
# SyntaxError: can't assign to literal

# %%
a=1
b=2
a>b
# Out:
# False

# %%
a=1
b=2
a<b
# Out:
# True

# %%
x=5
x-6
# Out:
# -1

# %%
x=20
y=15
x*y
# Out:
# 300

# %%
x=20
y=15
(x*y)**2
# Out:
# 90000

# %%
### Below are python lessons

# %%
#'addition - X+5'
#'Subtraction - x-5'
#'Multiplication - x*5'
#'Division  (Float) x/5'
#'Modulus  x%5'

# %%
str((1,2,3))
# Out:
# '(1, 2, 3)'

# %%
bool("TRUE, FALSE")
# Out:
# True

# %%
bool("2,4")
# Out:
# True

# %%
type("True")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
a=bool(("True", "False"))

# %%
type(a)
# Out:
# bool

# %%
int(a)
# Out:
# 1

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %%
my_string="learning"
print('I love', my_string + " "+ "and"+  " " "reading")
# Out:
# I love learning and reading

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %%
my_string="Adeniyi"
print('my details are:', my_string+ " " + "Osun"+ " " "State")
# Out:
# my details are: Adeniyi Osun State

# %%
a= "are"
b= "mine"
c= "forever"
my_list = ["these", "list", a, b, c]
print(my_list)
# Out:
# ['these', 'list', 'are', 'mine', 'forever']

# %%
#This is to form a list of lists

my_list2=[[1,2,6,9], [6,5,9,3], ["a,b,c,d"]]
print(my_list2)
# Out:
# [[1, 2, 6, 9], [6, 5, 9, 3], ['a,b,c,d']]

# %%
my_list[0]
# Out:
# 'these'

# %%
my_list[2]
# Out:
# 'are'

# %%
my_list[-1]
# Out:
# 'forever'

# %%
my_list[-2]
# Out:
# 'mine'

# %%
my_list2[1][-2]
# Out:
# 9

# %%
my_list[1:4]  #This code is used to index a range from our list, if we need Observations 1 to 3 then we index 1:4
# Out:
# ['list', 'are', 'mine']

# %%
my_list[1:]
# Out:
# ['list', 'are', 'mine', 'forever']

# %%
my_list[:]
# Out:
# ['these', 'list', 'are', 'mine', 'forever']

# %%
my_list[:2]   #this type of indexing or range finding means(we didnt specify the starting point. Same can be done for no end)
# Out:
# ['these', 'list']

# %%
my_list2[:]
# Out:
# [[1, 2, 6, 9], [6, 5, 9, 3], ['a,b,c,d']]

# %%
my_list2 >4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f803730a9414> in <module>
# ----> 1 my_list2 >4
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
new_list = [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10]
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10]

# %%
new_list.index(10)
# Out:
# 12

# %%
new_list.index(11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-8c2cb337c43f> in <module>
# ----> 1 new_list.index(11)
#
# ValueError: 11 is not in list

# %%
new_list.index(1)
# Out:
# 0

# %%
new_list.index(2)
# Out:
# 1

# %%
#Here, this is the method to pop up suggestion to be used on python (by new_list. then press tab key or shift+tab) pressing shift+tab keys allow user to read documentation on python

new_list.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
#this function helps users to count the number of a particular observation or value in a list

new_list.count(5)
# Out:
# 4

# %%
new_list.count(5)
# Out:
# 4

# %%
#this helps us to append

new_list.append(11)
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11]

# %%
#new_list.append([12, 13])

# %%
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11]

# %%
new_list.extend([12, 13])

# %%
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 12, 13]

# %%
new_list.clear([12, 13])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-ac1da247b8c0> in <module>
# ----> 1 new_list.clear([12, 13])
#
# TypeError: clear() takes no arguments (1 given)

# %%
new_list.pop(-1)
# Out:
# 13

# %%
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 12]

# %%
new_list.sort()

# %%
new_list
# Out:
# [1, 2, 3, 4, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 12]

# %%
new_list.insert(4, 50)

# %%
new_list
# Out:
# [1, 2, 3, 4, 50, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 12]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#numpy meanms Numberical Python. Use for algebraec, array function and matrices operations
#Nupy changes codes to rows and columns called array

# %%
#this is a convention in python 

import numpy as np

# %%
new_list
# Out:
# [1, 2, 3, 4, 50, 5, 5, 5, 5, 6, 7, 8, 9, 10, 11, 12]

# %%
#the code below is used to form our list into array

new_list_array = np.array(new_list)

# %%
new_list_array
# Out:
# array([ 1,  2,  3,  4, 50,  5,  5,  5,  5,  6,  7,  8,  9, 10, 11, 12])

# %%
my_array= np.array([[1, 2, 3, 5], [3, 5, 9, 8], [7, 6, 3, 7]])
my_array
# Out:
# array([[1, 2, 3, 5],
#        [3, 5, 9, 8],
#        [7, 6, 3, 7]])

# %%
#the code below is used to check the shape of our array (my_array.shape)

my_array.shape
# Out:
# (3, 4)

# %%
new_list_array.shape
# Out:
# (16,)

# %%
#the codes below are used to check the row and column in our array
new_list_array[0]
# Out:
# 1

# %%
my_array[:,0]
# Out:
# array([1, 3, 7])

# %%
my_array[:,1]
# Out:
# array([2, 5, 6])

# %%
my_array[:,2]
# Out:
# array([3, 9, 3])

# %%
my_array[0,:]
# Out:
# array([1, 2, 3, 5])

# %%
my_array[2, :]
# Out:
# array([7, 6, 3, 7])

# %%
my_array[1,2]
# Out:
# 9

# %%
my_array[1,3]
# Out:
# 8

# %%
my_array[2,3]
# Out:
# 7

# %%
my_array[1:3,2:4]
# Out:
# array([[9, 8],
#        [3, 7]])

# %%
self_array= np.array([[2, 4, 6, 8], [9, 3, 8, 7], [2, 5, 9, 8], [1, 6, 2, 3]])
self_array
# Out:
# array([[2, 4, 6, 8],
#        [9, 3, 8, 7],
#        [2, 5, 9, 8],
#        [1, 6, 2, 3]])

# %%
self_array[1:3,2]
# Out:
# array([8, 9])

# %%
##Assignments
#Get all numpy method
#state breifly what they are used for and create one example from each

# %%
nupy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-8e17f828a574> in <module>
# ----> 1 nupy
#
# NameError: name 'nupy' is not defined

# %%
#6th December, 2019 Friday being 3rd AI Class       NUMPY CLASS

# %%
#For loop

import numpy as np

# %%
def minus(x,y):
    try:
        return x - y
    except TypeError:
        return float(x) - float(y)

# %%
minus(100,25)
# Out:
# 75

# %%
def multiply(x,y,z):
    return x*y*z

# %%
multiply(10,2,5)
# Out:
# 100

# %%
#Lambda function  this is a function can only be used once after declaration

add_mine = lambda x : x + 75
add_mine(26)
# Out:
# 101

# %%
#for loop function (this code is used for iteration i.e. to look through a range of observations)

for x in range (3,9):
    print(x/3)
# Out:
# 1.0
# 1.3333333333333333
# 1.6666666666666667
# 2.0
# 2.3333333333333335
# 2.6666666666666665

# %%
# round  is a function for "rounding up the values to the nearest whole number"

for x in range (3,9):
    print(round(x/3))
# Out:
# 1
# 1
# 2
# 2
# 2
# 3

# %%
# The code below is used to DISPLAY the range of values in a specified observation

for x in range (3,9):

    print(x)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8

# %%
# The code below is used to PRINT or convert the output from float (Decimal) to intergeer (whole number). But please note that
#it will display the outcome without rounding up the values

for x in range (3,9):
    print(int(x/3))
# Out:
# 1
# 1
# 1
# 2
# 2
# 2

# %%
for i in [3, 6, 9, 12, 15, 18, 21]:
    print (range(i))
# Out:
# range(0, 3)
# range(0, 6)
# range(0, 9)
# range(0, 12)
# range(0, 15)
# range(0, 18)
# range(0, 21)

# %% [markdown]
# # PANDAS TUTORIAL

# %%
#PANDAS   
#There are 2 types of PANDAS  (i) Pandas Series  (ii) Pandas Dataframe
# (i) Pandas Series refers to a set of data or observation with single list of column
#(ii) Pandas Dataframe refers observations having rows and column
#PANDAS is used to read in data or import dataset

#EXAMPLES below

#df.dtype to check data type

# %%
import pandas as pd

# %%
df = pd.read_csv('train_Practise.csv')

#The code below is used for checking the data type

#df.dtypes
# Out:
# ward                  object
# total_households     float64
# total_individuals    float64
# target               float64
# dw_00                float64
#                       ...
# pw_08                  int64
# ADM4_PCODE            object
# lat                  float64
# lon                  float64
# NL                   float64
# Length: 63, dtype: object

# %%
#The code below is used for checking the shape of the data e.g. how many rows and columns

df.shape
# Out:
# (2822, 63)

# %%
#The code is used to print the data or values from the 1st observation to the fifth as default 

#df.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05  ...     pw_03     pw_04  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372  ...  0.002848  0.007537
# 1  0.001253  0.004402  0.000000  0.002301  0.001323  ...  0.014566  0.057127
# 2  0.004517  0.008891  0.003986  0.007735  0.000956  ...  0.057560  0.010358
# 3  0.000000  0.006129  0.000000  0.000813  0.037245  ...  0.000000  0.000669
# 4  0.000655  0.001473  0.000598  0.006999  0.000818  ...  0.004859  0.001290
#
# ...

# %%
#The code below is used to print data from the 1st observation to the 20th observation.
#Note that u can input the size of observation you want to print inside the parenthesis

df.head(20)
# Out:
#                 ward  total_households  total_individuals     target  \
# 0   41601001: Ward 1        1674.45058         5888.20750  16.773757
# 1   41601002: Ward 2        1736.99230         6735.33812  21.496661
# 2   41601003: Ward 3        2403.57591         7273.04995  10.931425
# 3   41601004: Ward 4        1740.78737         5734.49046  23.119257
# 4   41601005: Ward 5        1730.51451         6657.23835  13.652252
# 5   41601006: Ward 6        1956.16888         6340.05782  25.249880
# 6   41602001: Ward 1        1966.40293         6230.77491  19.984585
# 7   41602002: Ward 2        2214.44168         6873.93123  16.511081
# 8   41602003: Ward 3        2022.95917         6736.49015  25.962117
# 9   41602004: Ward 4        1775.53323         5682.10110  21.744166
# 10  41602005: Ward 5        1869.05745         5738.19717  18.915248
# 11  41602006: Ward 6        1935.43743         5729.28787  23.339213
# 12  41602007: Ward 7        1878.04354         5719.76277  18.927365
# ...

# %%
#The code is used to print the data or values from the last (5th) observation to the 1st as default

df.tail()
# Out:
#                   ward  total_households  total_individuals     target  \
# 2817  34503001: Ward 1        3261.68067        11551.56486   6.393480
# 2818  34503002: Ward 2        1463.06432         7908.90411  15.668000
# 2819  34503003: Ward 3        1395.18881         6242.37527  13.238795
# 2820  34503004: Ward 4        1679.66964         8014.73089  17.639523
# 2821  34503005: Ward 5        3008.38687         7899.36498  12.457680
#
#          dw_00     dw_01     dw_02     dw_03     dw_04     dw_05  ...  \
# 2817  0.874972  0.003146  0.017230  0.004735  0.048888  0.000654  ...
# 2818  0.636235  0.002262  0.010433  0.000000  0.003030  0.000000  ...
# 2819  0.855975  0.006601  0.061118  0.000812  0.003912  0.000812  ...
# 2820  0.792552  0.004423  0.016099  0.000000  0.000674  0.000000  ...
# 2821  0.254215  0.003310  0.121954  0.000000  0.001770  0.001023  ...
#
#          pw_03     pw_04     pw_05     pw_06  pw_07  pw_08  ADM4_PCODE  \
# ...

# %%
#This is used to print the observations from the tail (end) in this case 20th observation to the 1st observation

#df.tail(20)
# Out:
#                    ward  total_households  total_individuals     target  \
# 2802  34501014: Ward 14        1403.31972         5181.55434  34.092909
# 2803  34501015: Ward 15        1413.31960         5945.02570  29.202312
# 2804   34502001: Ward 1        1667.75905         6121.10372   5.443823
# 2805   34502002: Ward 2        2676.90014         8751.40681  21.315342
# 2806   34502003: Ward 3        3495.97358         9996.25986  20.457931
# 2807   34502004: Ward 4        1635.03317         5824.21418  24.327679
# 2808   34502005: Ward 5        1006.33326         3292.02866  29.062083
# 2809   34502006: Ward 6        2895.80664         8819.14348  21.859571
# 2810   34502007: Ward 7        1588.02370         5818.82566  32.908719
# 2811   34502008: Ward 8        1794.27941         5990.58572  29.413963
# 2812   34502009: Ward 9         964.17366         3784.03630  30.593096
# 2813  34502010: Ward 10        2915.45302        11176.02950  26.177120
# ...

# %%
# The code below is used to print the list of heads or column heads in the dataset

df.columns
# Out:
# Index(['ward', 'total_households', 'total_individuals', 'target', 'dw_00',
#        'dw_01', 'dw_02', 'dw_03', 'dw_04', 'dw_05', 'dw_06', 'dw_07', 'dw_08',
#        'dw_09', 'dw_10', 'dw_11', 'dw_12', 'dw_13', 'psa_00', 'psa_01',
#        'psa_02', 'psa_03', 'psa_04', 'stv_00', 'stv_01', 'car_00', 'car_01',
#        'lln_00', 'lln_01', 'lan_00', 'lan_01', 'lan_02', 'lan_03', 'lan_04',
#        'lan_05', 'lan_06', 'lan_07', 'lan_08', 'lan_09', 'lan_10', 'lan_11',
#        'lan_12', 'lan_13', 'lan_14', 'pg_00', 'pg_01', 'pg_02', 'pg_03',
#        'pg_04', 'lgt_00', 'pw_00', 'pw_01', 'pw_02', 'pw_03', 'pw_04', 'pw_05',
#        'pw_06', 'pw_07', 'pw_08', 'ADM4_PCODE', 'lat', 'lon', 'NL'],
#       dtype='object')

# %%
# The code below is used to display the list of dataset if there are missing values or not, data type e.g float, integer etc

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 63 columns):
# ward                 2822 non-null object
# total_households     2822 non-null float64
# total_individuals    2822 non-null float64
# target               2822 non-null float64
# dw_00                2822 non-null float64
# dw_01                2822 non-null float64
# dw_02                2822 non-null float64
# dw_03                2822 non-null float64
# dw_04                2822 non-null float64
# dw_05                2822 non-null float64
# dw_06                2822 non-null float64
# dw_07                2822 non-null float64
# dw_08                2822 non-null float64
# dw_09                2822 non-null float64
# dw_10                2822 non-null float64
# dw_11                2822 non-null float64
# dw_12                2822 non-null int64
# dw_13                2822 non-null int64
# psa_00               2822 non-null float64
# ...

# %%
# The code below is used to print the SAMPLE OF THE WHOLE  dataset. but default is 1 sample (i.e. no value inside the bracket below)

df.sample()
# Out:
#                   ward  total_households  total_individuals     target  \
# 2086  83102004: Ward 4        2877.88124        10112.94113  19.988166
#
#          dw_00     dw_01     dw_02  dw_03     dw_04     dw_05  ...     pw_03  \
# 2086  0.757257  0.002585  0.001503    0.0  0.000828  0.000897  ...  0.006053
#
#          pw_04    pw_05     pw_06  pw_07  pw_08  ADM4_PCODE        lat  \
# 2086  0.003692  0.00076  0.013284      0      0   ZA8312004 -25.848925
#
#             lon         NL
# 2086  29.124926  32.246137
#
# [1 rows x 63 columns]

# %%
# The code below is used to print 20 SAMPLE OF THE WHOLE  dataset. but default is 1 sample (i.e.  value 20 inside the bracket below)

df.sample(20)
# Out:
#                     ward  total_households  total_individuals     target  \
# 96      41901007: Ward 7        2348.32625         7130.76547  30.165754
# 1899   94702014: Ward 14        3821.27850        12942.95027  23.528938
# 2496   63803030: Ward 30        3453.88951         8842.25240  30.896553
# 1491  59500101: Ward 101        9936.30020        25459.60705  21.994916
# 1172    52405002: Ward 2        2136.35070         9886.62612  39.028982
# 1692   93404028: Ward 28        4453.73444        15854.22046  30.268280
# 1398    59500008: Ward 8       10166.48598        35539.33710  14.507857
# 607    79800066: Ward 66       13998.59911        45451.44616  11.817546
# 2403    63704003: Ward 3        1425.10650         4907.86641  11.047106
# 2655    30602006: Ward 6        1666.71059         6111.28938  18.792936
# 2639    64004005: Ward 5        1629.56619         6172.19051   7.507126
# 18      41603005: Ward 5        1552.08727         4762.15554  21.867528
# ...

# %%
df.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05  ...     pw_03     pw_04  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372  ...  0.002848  0.007537
# 1  0.001253  0.004402  0.000000  0.002301  0.001323  ...  0.014566  0.057127
# 2  0.004517  0.008891  0.003986  0.007735  0.000956  ...  0.057560  0.010358
# 3  0.000000  0.006129  0.000000  0.000813  0.037245  ...  0.000000  0.000669
# 4  0.000655  0.001473  0.000598  0.006999  0.000818  ...  0.004859  0.001290
#
# ...

# %%
# The code below is used to print the # SAMPLE DESCRIPTION OF THE WHOLE  dataset. I.E. DESCRIPTIVE STATISTICS OF THE DATASET

The df.describe()
# Out:
#        total_households  total_individuals       target        dw_00  \
# count       2822.000000        2822.000000  2822.000000  2822.000000
# mean        3665.281214       12869.130053    24.507554     0.712196
# std         3266.364522        9696.690518    10.294387     0.214035
# min            1.000000         402.000000     0.000000     0.000000
# 25%         1778.858235        7071.205695    16.751556     0.594212
# 50%         2398.249935        9366.989680    24.156670     0.766841
# 75%         3987.080563       14241.233015    32.226553     0.881708
# max        39684.942130       91716.746370    55.528423     0.994962
#
#              dw_01        dw_02        dw_03        dw_04        dw_05  \
# count  2822.000000  2822.000000  2822.000000  2822.000000  2822.000000
# mean      0.092616     0.032043     0.006057     0.008665     0.006289
# std       0.182852     0.080253     0.019374     0.030697     0.024606
# ...

# %%
#The code below is used to find CORRELATION IN THE DATASET

df.corr()
# Out:
#                    total_households  total_individuals    target     dw_00  \
# total_households           1.000000           0.959244 -0.374833 -0.226119
# total_individuals          0.959244           1.000000 -0.293827 -0.200350
# target                    -0.374833          -0.293827  1.000000  0.018461
# dw_00                     -0.226119          -0.200350  0.018461  1.000000
# dw_01                     -0.231304          -0.161183  0.458206 -0.614702
# ...                             ...                ...       ...       ...
# pw_07                           NaN                NaN       NaN       NaN
# pw_08                           NaN                NaN       NaN       NaN
# lat                        0.063018           0.039653  0.120381  0.348089
# lon                        0.032249           0.104198  0.347088 -0.152692
# NL                         0.708701           0.684853 -0.514398 -0.133895
#
# ...

# %%
df['ward'].value_counts()
# Out:
# 83102034: Ward 34    1
# 79900073: Ward 73    1
# 52702012: Ward 12    1
# 30903001: Ward 1     1
# 52705013: Ward 13    1
#                     ..
# 79700023: Ward 23    1
# 30901026: Ward 26    1
# 52804023: Ward 23    1
# 83005002: Ward 2     1
# 52102010: Ward 10    1
# Name: ward, Length: 2822, dtype: int64

# %%
df.ward
# Out:
# 0       41601001: Ward 1
# 1       41601002: Ward 2
# 2       41601003: Ward 3
# 3       41601004: Ward 4
# 4       41601005: Ward 5
#               ...
# 2817    34503001: Ward 1
# 2818    34503002: Ward 2
# 2819    34503003: Ward 3
# 2820    34503004: Ward 4
# 2821    34503005: Ward 5
# Name: ward, Length: 2822, dtype: object

# %%
type(df.ward)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['total_households'].value_counts()
# Out:
# 7068.04709     1
# 1951.79282     1
# 1556.93774     1
# 2086.09070     1
# 5698.44972     1
#               ..
# 2019.63474     1
# 9577.94399     1
# 12280.92254    1
# 4369.07002     1
# 178.00000      1
# Name: total_households, Length: 2822, dtype: int64

# %%
df.mode()
# Out:
#                    ward  total_households  total_individuals     target  \
# 0      30601001: Ward 1           1.00000          402.00000   0.000000
# 1      30601002: Ward 2         178.00000          896.02641   1.671886
# 2      30601003: Ward 3         244.30116         1266.29666   2.672209
# 3      30601004: Ward 4         440.90597         1586.70575   3.234013
# 4      30602001: Ward 1         511.53265         1734.05250   3.237956
# ...                 ...               ...                ...        ...
# 2817  94703027: Ward 27       22805.57563        59086.15228  52.010403
# 2818  94703028: Ward 28       22986.82397        62240.87246  52.171511
# 2819  94703029: Ward 29       23544.17746        63287.85852  52.248392
# 2820  94703030: Ward 30       28935.65396        84536.12012  52.601169
# 2821  94703031: Ward 31       39684.94213        91716.74637  55.528423
#
#          dw_00  dw_01  dw_02  dw_03  dw_04  dw_05  ...  pw_03  pw_04  pw_05  \
# ...

# %%
df.pg_00.mean()
# Out:
# 0.8621424599109138

# %%
#find MISSING VALUE

df.pg_00.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2817    False
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# Name: pg_00, Length: 2822, dtype: bool

# %%
df.skew()
# Out:
# total_households     2.715798
# total_individuals    2.164591
# target               0.109293
# dw_00               -1.027741
# dw_01                2.537747
#                        ...
# pw_07                0.000000
# pw_08                0.000000
# lat                 -0.024309
# lon                 -1.256801
# NL                   1.149866
# Length: 61, dtype: float64

# %%
df.kurtosis()
# Out:
# total_households     11.665419
# total_individuals     5.843852
# target               -0.698781
# dw_00                 0.430059
# dw_01                 5.765620
#                        ...
# pw_07                 0.000000
# pw_08                 0.000000
# lat                  -0.740603
# lon                   2.770354
# NL                    0.067994
# Length: 61, dtype: float64

# %%
pd.crosstab(df.ward, df.lat)
# Out:
# lat                -32.490089  -31.888645  -31.814231  -31.665732  -31.469394  \
# ward
# 30601001: Ward 1            0           0           0           0           0
# 30601002: Ward 2            0           0           0           0           0
# 30601003: Ward 3            0           0           0           0           0
# 30601004: Ward 4            0           0           0           0           0
# 30602001: Ward 1            0           0           0           0           0
# ...                       ...         ...         ...         ...         ...
# 94703027: Ward 27           0           0           0           0           0
# 94703028: Ward 28           0           0           0           0           0
# 94703029: Ward 29           0           0           0           0           0
# 94703030: Ward 30           0           0           0           0           0
# 94703031: Ward 31           0           0           0           0           0
#
# ...

# %% [markdown]
# # DATAFRAME TUTORIAL

# %%
dff = pd.DataFrame({'A': [11, 21, 31],
                   'B': [12, 22, 32],
                   'c': [11, 18, 16]})

# %% [markdown]
# # DROP TUTORIAL

# %%
##Axis means the X and Y axis with x =0 while Y axis = 1   pls see the code below

df.drop(['lat', 'lon'], axis = 1, inplace = True)

# %%
df.drop('ADM4_PCODE', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['ward', 'total_households', 'total_individuals', 'target', 'dw_00',
#        'dw_01', 'dw_02', 'dw_03', 'dw_04', 'dw_05', 'dw_06', 'dw_07', 'dw_08',
#        'dw_09', 'dw_10', 'dw_11', 'dw_12', 'dw_13', 'psa_00', 'psa_01',
#        'psa_02', 'psa_03', 'psa_04', 'stv_00', 'stv_01', 'car_00', 'car_01',
#        'lln_00', 'lln_01', 'lan_00', 'lan_01', 'lan_02', 'lan_03', 'lan_04',
#        'lan_05', 'lan_06', 'lan_07', 'lan_08', 'lan_09', 'lan_10', 'lan_11',
#        'lan_12', 'lan_13', 'lan_14', 'pg_00', 'pg_01', 'pg_02', 'pg_03',
#        'pg_04', 'lgt_00', 'pw_00', 'pw_01', 'pw_02', 'pw_03', 'pw_04', 'pw_05',
#        'pw_06', 'pw_07', 'pw_08', 'NL'],
#       dtype='object')

# %% [markdown]
# # 12th December, 2019       PANDAS CLASS CONTINUATION

# %% [markdown]
# ## Assignments
# ### Get all PANDAS method OR OPERATIONS
# ### State breifly what they are used for and create one example from each

# %% [markdown]
# # ===============================================================

# %% [markdown]
# # Creating Github and other Community accounts

# %%
# Downloade VS Code     or gitbash   on google.com 
#The VS Code is used to upload our code to the www.GITHUB.COM account and we make it private
#press CTRL + backtick  key on the keyboard (backtick key is the key under the ESC key, beside 1) is shortcut to VS notepad
